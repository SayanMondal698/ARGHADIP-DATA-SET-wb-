# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3612ea18-6642-444e-aa01-4ab3fa756def" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3612ea18-6642-444e-aa01-4ab3fa756def">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
west_bengal=pd.read_csv('west_bengal.csv')
west_bengal
# Out:
#                 candidate         constituency   party  criminal_cases  \
# 0        Abdul Hai Mallik                 ONDA     IND               0
# 1      Abdur Razzak Molla                FALTA     INC               2
# 2    Abhijit Bhattacharya              PURULIA     IND               0
# 3     Abir Chandra Mandal              CHHATNA     IND               0
# 4        Adhikari Suvendu            NANDIGRAM     BJP               1
# ..                    ...                  ...     ...             ...
# 562          Uttam Naskar       BISHNUPUR (SC)     IND               0
# 563   Uttara Singha Hazra              GARBETA    AITC               1
# 564    Vibekananda Mondal  ULUBERIA UTTAR (SC)     IND               0
# 565     Vivekananda Bauri    RAGHUNATHPUR (SC)     BJP               0
# 566    Yamini Kanta Mandi        MANBAZAR (ST)  CPI(M)               0
#
#                  education  total_assets  liabilities
# 0                 8th Pass        160171            0
# ...

# %%
west_bengal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   candidate       567 non-null    object
#  1   constituency    567 non-null    object
#  2   party           567 non-null    object
#  3   criminal_cases  567 non-null    int64
#  4   education       567 non-null    object
#  5   total_assets    567 non-null    int64
#  6   liabilities     567 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 31.1+ KB

# %%
west_bengal.describe()
# Out:
#        criminal_cases  total_assets   liabilities
# count      567.000000  5.670000e+02  5.670000e+02
# mean         0.839506  7.109702e+06  8.508290e+05
# std          2.467597  2.341999e+07  3.407338e+06
# min          0.000000  0.000000e+00  0.000000e+00
# 25%          0.000000  3.652070e+05  0.000000e+00
# 50%          0.000000  1.743550e+06  0.000000e+00
# 75%          1.000000  5.911767e+06  2.540000e+05
# max         27.000000  4.302504e+08  4.268688e+07

# %%
west_bengal.head()
# Out:
#               candidate constituency party  criminal_cases  \
# 0      Abdul Hai Mallik         ONDA   IND               0
# 1    Abdur Razzak Molla        FALTA   INC               2
# 2  Abhijit Bhattacharya      PURULIA   IND               0
# 3   Abir Chandra Mandal      CHHATNA   IND               0
# 4      Adhikari Suvendu    NANDIGRAM   BJP               1
#
#                education  total_assets  liabilities
# 0               8th Pass        160171            0
# 1              10th Pass       2650450            0
# 2          Post Graduate       4439532       375000
# 3  Graduate Professional        809000            0
# 4          Post Graduate      10552749            0

# %%
west_bengal.head(10)
# Out:
#               candidate    constituency                party  criminal_cases  \
# 0      Abdul Hai Mallik            ONDA                  IND               0
# 1    Abdur Razzak Molla           FALTA                  INC               2
# 2  Abhijit Bhattacharya         PURULIA                  IND               0
# 3   Abir Chandra Mandal         CHHATNA                  IND               0
# 4      Adhikari Suvendu       NANDIGRAM                  BJP               1
# 5     Adhikary Nilanjan      NANDAKUMAR                  BJP               0
# 6    Aditya Kumar Bauri    SALTORA (SC)  Bahujan Mukti Party               0
# 7         Aditya Mahato         PURULIA                  IND               0
# 8          Aditya Manik        KHANAKUL                  IND               0
# 9       Agniswar Naskar  BISHNUPUR (SC)                  BJP               1
#
#                education  total_assets  liabilities
# 0               8th Pass        160171            0
# ...

# %%
west_bengal.iloc[25:32]
# Out:
#                candidate      constituency                          party  \
# 25  Amitabha Chakraborti          SHYAMPUR                            INC
# 26         Amitav Naskar     JAYNAGAR (SC)                         RPI(A)
# 27          Amulya Maity            SABANG                            BJP
# 28          Ananda Kundu  BARUIPUR PASCHIM                            IND
# 29           Anandi Tudu        BALARAMPUR                            BSP
# 30           Anath Bauri           CHHATNA                            IND
# 31   Anil Chandra Mondal       GOSABA (SC)  Revolutionary Socialist Party
#
#     criminal_cases      education  total_assets  liabilities
# 25               2  Post Graduate       5999167            0
# 26               0  Post Graduate       1220000            0
# 27               1       Graduate       4047204            0
# 28               0     Illiterate         30026            0
# 29               0      10th Pass             0            0
# ...

# %%
west_bengal.ind=west_bengal.sort_values('criminal_cases')
west_bengal.ind
# Out:
# <ipython-input-15-af4aabea488e>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   west_bengal.ind=west_bengal.sort_values('criminal_cases')
#                    candidate     constituency  \
# 0           Abdul Hai Mallik             ONDA
# 132        D. Madhusudan Rao  KHARAGPUR SADAR
# 133         Debabrata Mondal     BASANTI (SC)
# 135           Debajyoti Basu       SATGACHHIA
# 136          Debashis Barman           SABANG
# ..                       ...              ...
# 537        Tapan Kumar Ghosh          GARBETA
# 459            Sk. Mainuddin        JANGIPARA
# 90             Bharati Ghosh            DEBRA
# 204            Himangshu Das     KHEJURI (SC)
# 86   Barun Pramanik (Chitta)      GOSABA (SC)
#
#                                party  criminal_cases      education  \
# 0                                IND               0       8th Pass
# ...

# %%
west_bengal=west_bengal.sort_values('criminal_cases')
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
ind_grt_10K=west_bengal[west_bengal['criminal_cases']>1]
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
west_bengal_grt_1=west_bengal[west_bengal['criminal_cases']>1]
west_bengal_grt_1
# Out:
#                    candidate      constituency  \
# 335             Phiroja Bibi  PANSKURA PASCHIM
# 137              Debasis Das      KANTHI UTTAR
# 216        Jaykrishna Haldar      KULTALI (SC)
# 223            Joydeb Halder  MANDIRBAZAR (SC)
# 266            Manik Bhaumik             MOYNA
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 335                            AITC               2       8th Pass
# 137                             IND               2      12th Pass
# 216                         SUCI(C)               2      10th Pass
# 223                            AITC               2      10th Pass
# ...

# %%
west_bengal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 567 entries, 0 to 86
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   candidate       567 non-null    object
#  1   constituency    567 non-null    object
#  2   party           567 non-null    object
#  3   criminal_cases  567 non-null    int64
#  4   education       567 non-null    object
#  5   total_assets    567 non-null    int64
#  6   liabilities     567 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 35.4+ KB

# %%
west_bengal_inc=west_bengal[(west_bengal['constituency']=='Rashtriya Secular Majlis Party	') | (west_bengal['constituency']=='Indian National Congress	')]
west_bengal_inc
# Out:
# Empty DataFrame
# Columns: [candidate, constituency, party, criminal_cases, education, total_assets, liabilities]
# Index: []

# %%
west_bengal['total']=west_bengal['total_assets']+west_bengal['criminal_cases']
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
west_bengal['total_info']=west_bengal['total_assets']+west_bengal['liabilities']
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
west_bengal['p_ind']=west_bengal['total_assets']+west_bengal['total']
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
west_bengal['p_ind']=west_bengal['liabilities']+west_bengal['total_info']
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
west_bengal.head()
# Out:
#              candidate      constituency                party  criminal_cases  \
# 0     Abdul Hai Mallik              ONDA                  IND               0
# 367    Ramkrishna Maji         TALDANGRA                  IND               0
# 364      Ramesh Khanra            BAGNAN                  IND               0
# 361  Ram Sankar Halder      KULTALI (SC)               CPI(M)               0
# 360  Ram Prasad Ghorai  ULUBERIA DAKSHIN  Indian Unity Centre               0
#
#      education  total_assets  liabilities    total  total_info    p_ind
# 0     8th Pass        160171            0   160171      160171   160171
# 367  12th Pass         18451            0    18451       18451    18451
# 364  12th Pass        308246            0   308246      308246   308246
# 361  12th Pass       1743550            0  1743550     1743550  1743550
# 360  10th Pass        224700            0   224700      224700   224700

# %%
west_bengal['ind_per_10K']=10000*west_bengal['criminal_cases']/west_bengal['total_assets']
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
west_bengal['ind_per_10K']=10000*west_bengal['p_ind']/west_bengal['liabilities']
west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...

# %%
high_west_bengal=west_bengal[west_bengal['ind_per_10K']>20000]
high_west_bengal
# Out:
# Empty DataFrame
# Columns: [candidate, constituency, party, criminal_cases, education, total_assets, liabilities, total, total_info, p_ind, ind_per_10K]
# Index: []

# %%
high_west_bengal=west_bengal[west_bengal['ind_per_10K']>20000]
high_west_bengal
# Out:
#                    candidate      constituency  \
# 0           Abdul Hai Mallik              ONDA
# 367          Ramkrishna Maji         TALDANGRA
# 364            Ramesh Khanra            BAGNAN
# 361        Ram Sankar Halder      KULTALI (SC)
# 360        Ram Prasad Ghorai  ULUBERIA DAKSHIN
# ..                       ...               ...
# 537        Tapan Kumar Ghosh           GARBETA
# 459            Sk. Mainuddin         JANGIPARA
# 90             Bharati Ghosh             DEBRA
# 204            Himangshu Das      KHEJURI (SC)
# 86   Barun Pramanik (Chitta)       GOSABA (SC)
#
#                               party  criminal_cases      education  \
# 0                               IND               0       8th Pass
# 367                             IND               0      12th Pass
# 364                             IND               0      12th Pass
# 361                          CPI(M)               0      12th Pass
# ...
